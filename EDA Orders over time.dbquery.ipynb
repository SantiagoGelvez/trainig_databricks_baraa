-- %%
-- Total orders over the time
SELECT
    date_trunc('month', order_date) AS month,
    SUM(sales_amount) AS total
FROM fact_sales
GROUP BY date_trunc('month', order_date)
;
-- Out:
-- Databricks visualization. Run in Databricks to view.
