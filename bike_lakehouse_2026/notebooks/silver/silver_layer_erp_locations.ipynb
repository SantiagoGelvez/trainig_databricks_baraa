# %%
import sys
sys.path.append("../..")

import pyspark.sql.functions as F

import common.transformations as ct
from common.io import read_table, write_table
from common.config import bronze_table, silver_table

# %%
RENAME_MAP = {
    'CID': 'customer_id',
    'CNTRY': 'country'
}

COUNTRY_MAP = {
    'US': 'United States',
    'USA': 'United States',
    'CA': 'Canada',
    'DE': 'Germany',
    'FR': 'France',
    'AU': 'Australia',
    'UK': 'United Kingdom',
    'UNITED STATES': 'United States',
    'CANADA': 'Canada',
    'GERMANY': 'Germany',
    'FRANCE': 'France',
    'AUSTRALIA': 'Australia',
    'UNITED KINGDOM': 'United Kingdom'
}

# %%
df = read_table(spark, bronze_table('erp_loc_a101'))
df = ct.trim_string_columns(df)

# %%
df = ct.map_codes_to_labels(df, 'CNTRY', COUNTRY_MAP)

# %%
df = df.withColumn('CID', F.replace(F.col('CID'), F.lit('-'), F.lit('')))

# %%
df = ct.rename_columns(df, RENAME_MAP)

# %%
write_table(df, silver_table('erp_locations'))

# %%
# %sql
SELECT * FROM baraa_dev_project.silver.erp_locations LIMIT 50
