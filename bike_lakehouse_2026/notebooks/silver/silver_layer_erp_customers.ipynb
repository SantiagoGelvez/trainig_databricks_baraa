# %%
import sys
sys.path.append("../..")

# %%
import pyspark.sql.functions as F

import common.transformations as ct
from common.io import read_table, write_table
from common.config import bronze_table, silver_table

# %%
RENAME_MAP = {
    'CID': 'customer_id',
    'BDATE': 'birth_date',
    'GEN': 'gender',
}

GENDER_MAP = {
    'F': 'Female',
    'M': 'Male',
    'FEMALE': 'Female',
    'MALE': 'Male',
}

# %%
df = read_table(spark, bronze_table('erp_cust_az12'))
df.display()
df = ct.trim_string_columns(df)

# %%
df = df.withColumn('CID', F.substring('CID', 4, F.length('CID')))

# %%
df = ct.map_codes_to_labels(df, 'GEN', GENDER_MAP)

# %%
df = ct.rename_columns(df, RENAME_MAP)

# %%
write_table(df, silver_table('erp_customers'))

# %%
# %sql
SELECT * FROM baraa_dev_project.silver.erp_customers LIMIT 50
